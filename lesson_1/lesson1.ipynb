# %%
# Task 1
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.title("Lesson 1")
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Task 2

img = cv2.imread("test.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
# Task 3

img = cv2.imread("test.jpg")

# Split the image into the three colour channels
red, green, blue = cv2.split(img)

# Compose the image in the RGB colour space
img1 = cv2.merge([red, green, blue])

# print(green.shape)

# Compose the image in the RBG colour space
img2 = cv2.merge([red, blue, green])

# Compose the image in the GRB colour space
img3 = cv2.merge([green, red, blue])

# Compose the image in the BGR colour space
img4 = cv2.merge([blue, green, red])

# Create the collage
out1 = np.hstack([img1, img2])
out2 = np.hstack([img3, img4])
out = np.vstack([out1, out2])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(2559.5), np.float64(-0.5))

# %%
# Task 4

# Load an image (you can freely chose any image you like)
img = cv2.imread("test.jpg")
# Convert it to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

flipped_lr = np.fliplr(img)
flipped_ud = np.flipud(img)
flipped_lrud = np.flipud(flipped_lr)

# Make a collage
out = np.vstack([np.hstack([img, flipped_lr]), np.hstack([flipped_ud, flipped_lrud])])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(2559.5), np.float64(-0.5))
