# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.title("Lesson 1")
plt.rcParams['figure.figsize'] = [15, 10]

# %%
import cv2

img = cv2.imread("test.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 img = cv2.imread("test.jpg")
#       4 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ----> 6 plt.imshow(img_rgb)
#
# NameError: name 'plt' is not defined

# %%
import cv2

img = cv2.imread("test.jpg")

# Split the image into the three colour channels
red, green, blue = cv2.split(img)

# Compose the image in the RGB colour space
img1 = cv2.merge([red, green, blue])

# print(green.shape)

# Compose the image in the RBG colour space
img2 = cv2.merge([green, blue, red])

# Compose the image in the GRB colour space
img3 = cv2.merge([green, red, blue])

# Compose the image in the BGR colour space
img4 = cv2.merge([blue, green, red])

# Create the collage
out1 = np.hstack([img1, img2])
out2 = np.hstack([img3, img4])
out = np.vstack([out1, out2])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      20 img4 = cv2.merge([blue, green, red])
#      22 # Create the collage
# ---> 23 out1 = np.hstack([img1, img2])
#      24 out2 = np.hstack([img3, img4])
#      25 out = np.vstack([out1, out2])
#
# NameError: name 'np' is not defined

# %%
# Load an image (you can freely chose any image you like)
img = cv2.imread("test.jpg")
# Convert it to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

flipped_lr = np.fliplr(img)
flipped_ud = np.flipud(img)

# Make a collage
out = np.hstack([flipped_ud, flipped_lr])

# Plot the collage
plt.imshow(out)
plt.axis(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 # Convert it to RGB
#       4 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ----> 6 flipped_lr = np.fliplr(img)
#       7 flipped_ud = np.flipud(img)
#       9 # Make a collage
#
# NameError: name 'np' is not defined
